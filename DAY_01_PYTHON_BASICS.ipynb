# %%
#1 print name,age,college
print('bhargava')
print('19')
print('vitap')
# Out:
# bhargava
# 19
# vitap

# %%
#2 Store name,age,city in variables and print them.
my_name = 'Bhargava'
my_age = '19'
my_city = 'vijayawada'
print(my_name,my_age,my_city)
# Out:
# Bhargava 19 vijayawada

# %%
#3 Take your name as input and print hello bhargava welcome to python
my_name = input('my name: ')
print("hello "  + my_name +   " welcome to python")
# Out:
# my name:  Bhargava
# hello Bhargava welcome to python

# %%
#4 Take 2 numbers as input and print there sum
my_age = input('My age: ')
my_weight = input('My weight: ')
print(int(my_age)+int(my_weight))
# Out:
# My age:  19
# My weight:  65
# 84

# %%
#5 Take your age as input and print you are 20 years old
my_age = input('my age: ')
print('you are ' + (my_age) + ' years old')
# Out:
# my age:  20
# you are 20 years old

# %%
#6 Area of rectangle

length = float(input("enter length: "))
breadth = float(input("enter breadth: "))
area = length*breadth
print("area of rectangle: ", area)
# Out:
# enter length:  25
# enter breadth:  60
# area of rectangle:  1500.0

# %%
#7 Area of circle
radius = float(input("enter radius: "))
area = 3.14*radius*radius
print("Area of circle: ", area)
# Out:
# enter radius:  30
# Area of circle:  2826.0

# %%
#8 Celsius to fahrenheit
celsius = float(input("enter temperature in celsius: "))
fahrenheit = (celsius*9/5)+32
print("temperature in fahrenheit: ", fahrenheit)
# Out:
# enter temperature in celsius:  30
# temperature in fahrenheit:  86.0

# %%
#9 swap two numbers using a temporary variable
a = int(input("enter first number: "))
b = int(input('enter second number: '))
temp = a
a = b
b = temp
print("after swapping: ")
print("first number: ", a)
print("second number: ", b)
# Out:
# enter first number:  20
# enter second number:  25
# after swapping:
# first number:  25
# second number:  20

# %%
#10 simple interest
principal = float(input("enter principal amount: "))
rate = float(input("enter rate of interest: "))
time = float(input("enter time(years): "))
simple_interest = (principal * rate * time)/100
print("simple_interest: ", simple_interest)
# Out:
# enter principal amount:  50000
# enter rate of interest:  5
# enter time(years):  2
# simple_interest:  5000.0

# %%
#11 Find the square of number
number = float(input("enter a number: "))
square = number*number
print("square: ", square)
# Out:
# enter a number:  30
# square:  900.0

# %%
#12 find the cube of a number
number = float(input("enter a number: "))
square = number*number*number
print("square: ", square)
# Out:
# enter a number:  20
# square:  8000.0

# %%
#13 calculate the average of three numbers
num1 = float(input("enter 1st number: "))
num2 = float(input("enter a number: "))
num3 = float(input("enter a number: "))
average = (num1+num2+num3)/3
print("average: ", average)
# Out:
# enter 1st number:  16
# enter a number:  20
# enter a number:  80
# average:  38.666666666666664

# %%
#14 convert kilograms to grams
kg = float(input("enter weight in kg: "))
grams = kg*1000
print('weight in grams: ', grams)
# Out:
# enter weight in kg:  40
# weight in grams:  40000.0

# %%
#15 convert minute into hours and remaining minutes
minutes = int(input("enter total minutes: "))
hours = minutes//60
remaining_minutes = minutes%60
print("hours: ", hours)
print("remaining minutes: ", remaining_minutes)
# Out:
# enter total minutes:  90
# hours:  1
# remaining minutes:  30
